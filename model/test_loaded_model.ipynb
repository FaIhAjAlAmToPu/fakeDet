# %%
import joblib

# Load the saved pipeline
model = joblib.load('/kaggle/input/classifier-final-model/gradient_boost_model.pkl')

inputs = [
    "Aliens spotted in the White House!",
    "Stock markets showed positive growth today despite inflation."
]

predictions = model.predict(inputs)

for text, pred in zip(inputs, predictions):
    print(f"Input: {text}\nPrediction: {'REAL' if pred else 'FAKE'}\n")
# Out:
# Input: Aliens spotted in the White House!
# Prediction: REAL
#
# Input: Stock markets showed positive growth today despite inflation.
# Prediction: REAL
